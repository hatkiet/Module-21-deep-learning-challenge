# %% [markdown]
# <a href="https://colab.research.google.com/github/hatkiet/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
columns_to_drop = ["EIN", "NAME"]
application_df = application_df.drop(columns = columns_to_drop)

# Verify
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column by using 'nunique()'.
print(application_df.nunique())
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_type_counts = application_df["APPLICATION_TYPE"].value_counts()
application_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value (i.e., 500) and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_type_counts[application_type_counts < 1500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# Other     5720
# T4        1542
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df["CLASSIFICATION"].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_more_than_1 = classification_counts[classification_counts > 1]
print(classification_counts_more_than_1)
print(f"Length: {len(classification_counts_more_than_1)}")
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64
# Length: 45

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 1900].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     4144
# C3000     1918
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_application_df = pd.get_dummies(application_df)
numeric_application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                    True
# 1       1   108590              1                   False
# 2       1     5000              0                    True
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  AFFILIATION_CompanySponsored  \
# 0                False                False                         False
# 1                 True                False                         False
# 2                False                False                          True
# 3                 True                False                          True
# 4                 True                False                         False
#
#    AFFILIATION_Family/Parent  AFFILIATION_Independent  AFFILIATION_National  \
# 0                      False                     True                 False
# 1                      False                     True                 False
# 2                      False                    False                 False
# 3                      False                    False                 False
# 4                      False                     True                 False
#
#    ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0  ...              False                   False                     False
# 1  ...               True                   False                     False
# 2  ...              False                   False                     False
# 3  ...              False                    True                     False
# 4  ...              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 37 columns]

# %%
# # Split our preprocessed data into our features and target arrays #Refs: Module 21/day2/Act06-07
y = numeric_application_df["IS_SUCCESSFUL"].values
X = numeric_application_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep learning neural network, i.e., the number of input features and hidden nodes for each layer.
number_input_features = X_train.shape[1]

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=20, activation="softmax"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=10, activation="sigmoid"))


# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1110
#
#  dense_1 (Dense)             (None, 20)                620
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1951 (7.62 KB)
# Trainable params: 1951 (7.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 2ms/step - loss: 0.6237 - accuracy: 0.6794
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7203
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5740 - accuracy: 0.7219
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5720 - accuracy: 0.7219
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5702 - accuracy: 0.7233
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5688 - accuracy: 0.7226
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5681 - accuracy: 0.7236
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5665 - accuracy: 0.7245
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5660 - accuracy: 0.7245
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5652 - accuracy: 0.7246
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5648 - accuracy: 0.7251
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5642 - accuracy: 0.7249
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5639 - accuracy: 0.7246
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5632 - accuracy: 0.7251
# Epoch 15/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5630 - accuracy: 0.7249
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7255
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5626 - accuracy: 0.7257
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5626 - accuracy: 0.7257
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5623 - accuracy: 0.7256
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7258
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5618 - accuracy: 0.7258
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5617 - accuracy: 0.7261
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5613 - accuracy: 0.7259
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7265
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7261
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5612 - accuracy: 0.7265
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7258
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7264
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.7264
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5607 - accuracy: 0.7266
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5605 - accuracy: 0.7264
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.7259
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7266
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5605 - accuracy: 0.7266
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7266
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7265
# Epoch 37/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5602 - accuracy: 0.7278
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.7277
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7276
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7262
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5598 - accuracy: 0.7268
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5598 - accuracy: 0.7279
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5597 - accuracy: 0.7260
# Epoch 44/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7274
# Epoch 45/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5598 - accuracy: 0.7261
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5597 - accuracy: 0.7278
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5593 - accuracy: 0.7278
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5592 - accuracy: 0.7277
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5595 - accuracy: 0.7273
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5594 - accuracy: 0.7271
# Epoch 51/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5593 - accuracy: 0.7278
# Epoch 52/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5594 - accuracy: 0.7279
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5594 - accuracy: 0.7274
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5589 - accuracy: 0.7280
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5588 - accuracy: 0.7272
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5593 - accuracy: 0.7279
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5588 - accuracy: 0.7273
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5588 - accuracy: 0.7279
# Epoch 59/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5588 - accuracy: 0.7282
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5586 - accuracy: 0.7285
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5589 - accuracy: 0.7270
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5585 - accuracy: 0.7276
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7283
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7281
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7286
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7275
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5584 - accuracy: 0.7283
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7273
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5585 - accuracy: 0.7281
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5584 - accuracy: 0.7275
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7285
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7283
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5582 - accuracy: 0.7289
# Epoch 74/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5583 - accuracy: 0.7278
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7287
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7293
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7285
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5580 - accuracy: 0.7286
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5580 - accuracy: 0.7282
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7286
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5578 - accuracy: 0.7289
# Epoch 82/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5577 - accuracy: 0.7289
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7288
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7288
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7282
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7287
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5577 - accuracy: 0.7289
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7287
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5575 - accuracy: 0.7280
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7289
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7283
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7290
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7283
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7291
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7293
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7289
# Epoch 97/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5571 - accuracy: 0.7292
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5569 - accuracy: 0.7293
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7284
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5568 - accuracy: 0.7293

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5681 - accuracy: 0.7198 - 1s/epoch - 4ms/step
# Loss: 0.5680710673332214, Accuracy: 0.7197667360305786

# %%
# Export our model to HDF5 file
nn_model.save("AlphabetSoupCharity_Optimazation_2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
